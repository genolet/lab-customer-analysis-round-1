# %% [markdown]
# # Instructions
#
# ### Read the three files into python as dataframes

# %%
import pandas as pd
df1 = pd.read_csv("./files_for_lab/csv_files/file1.csv")
display(df1.head())
df2 = pd.read_csv("./files_for_lab/csv_files/file2.csv")
display(df2.head())
df3 = pd.read_csv("./files_for_lab/csv_files/file3.csv")
display(df3.head())
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %% [markdown]
# ### Show the DataFrame's shape

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (4008, 11)
# (996, 11)
# (7070, 11)

# %% [markdown]
# ### Standardize header names

# %%
print(df1.columns == df2.columns)
print(df2.columns == df3.columns)

### This alternative is a bit more time consuming, but I could use this function is the future whenever I want to
### convert columns labels into lower cases 

def lowercases(x):
    y = []
    for i in x:
        a = i.lower()
        y.append(a)
    return y 

for i in  [df1, df2, df3]:
    i.columns = lowercases(i.columns)


### This second alternative is faster but I can only use it once 

#df1.columns = list(map(lambda x: x.lower(), df1.columns))
#df2.columns = list(map(lambda x: x.lower(), df2.columns))
#df2.columns = list(map(lambda x: x.lower(), df2.columns))

### Now I want to replace certain column labels 

display(df1.head())
display(df2.head())
display(df3.head())

df3 = df3.rename(columns = {"state":"st"})
display(df3.head())
# Out:
# [ True  True  True  True  True  True  True  True False False False]
# [ True False False  True False  True  True  True False False  True]
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# ...

# %% [markdown]
# ### Rearrange the columns in the dataframe as needed

# %%
print(df1.columns)

df2 = df2[['customer', 'st', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]
df3 = df3[['customer', 'st', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]

print(all(df1.columns == df2.columns))
print(all(df2.columns == df3.columns))
display(df1.head())
display(df2.head())
display(df3.head())
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')
# True
# True
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# ...

# %% [markdown]
# ### Concatenate the three dataframes

# %%
df = pd.concat([df1, df2, df3], axis = 0)
df.shape
df = df.reset_index(drop=True)
df
# Out:
#       customer          st gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# ### Which columns are numerical?

# %%
df.dtypes

### income, monthly premium auto and total claim amount are numerical
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %% [markdown]
# ### Which columns are categorical?

# %%
### customer, state, gender, education, customer lifetime value (this needs to be corrected), 
### number of open complaints, policy type and vehicle class

# %% [markdown]
# ### Perform the data cleaning operations mentioned so far in class
#
# *Delete the column education and the number of open complaints from the dataframe*

# %%
df = df.drop(["education", "number of open complaints"], axis = 1)
df
# Out:
#       customer          st gender customer lifetime value   income  \
# 0      RB50392  Washington    NaN                     NaN      0.0
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12071  TD14365  California      M             8163.890428      0.0
# 12072  UP19263  California      M             7524.442436  21941.0
# 12073  Y167826  California      M             2611.836866      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# *Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.*

# %%
print(df.isna().sum())
m_v = df[df["customer lifetime value"].isna() == True]
m_v

### There seem to be many rows with missing values in all of the columns (at least 2937). Are they the same rows? 


df['customer lifetime value'] =  pd.to_numeric(df['customer lifetime value'], errors='coerce')

### It says multiply by 100, but the numbers are already quite big. Maybe its divide? 

df['customer lifetime value'] = df['customer lifetime value']/100
print(df.dtypes)
df
# Out:
# customer                   2937
# st                         2937
# gender                     3059
# customer lifetime value    2944
# income                     2937
# monthly premium auto       2937
# policy type                2937
# vehicle class              2937
# total claim amount         2937
# dtype: int64
# customer                    object
# st                          object
# gender                      object
# customer lifetime value    float64
# income                     float64
# monthly premium auto       float64
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object
#       customer          st gender  customer lifetime value   income  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F                      NaN      0.0
# 2      AI49188      Nevada      F                      NaN  48767.0
# ...

# %% [markdown]
# *Check for duplicate rows in the data and remove if any.*

# %%
df = df.drop_duplicates()
df
# Out:
#       customer          st gender  customer lifetime value   income  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F                      NaN      0.0
# 2      AI49188      Nevada      F                      NaN  48767.0
# 3      WW63253  California      M                      NaN      0.0
# 4      GA49547  Washington      M                      NaN  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M               234.059880  71941.0
# 12070  PK87824  California      F                30.965112  21604.0
# 12071  TD14365  California      M                81.638904      0.0
# 12072  UP19263  California      M                75.244424  21941.0
# 12073  Y167826  California      M                26.118369      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# ...

# %% [markdown]
# *Filter out the data for customers who have an income of 0 or less.*

# %%
low_income = df[df["income"]>0]
print(low_income.shape)
low_income.head()
# Out:
# (6840, 9)
#   customer          st gender  customer lifetime value   income  \
# 2  AI49188      Nevada      F                      NaN  48767.0
# 4  GA49547  Washington      M                      NaN  36357.0
# 5  OC83172      Oregon      F                      NaN  62902.0
# 6  XZ87318      Oregon      F                      NaN  55350.0
# 8  DY87989      Oregon      M                      NaN  14072.0
#
#    monthly premium auto     policy type  vehicle class  total claim amount
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 4                  68.0   Personal Auto  Four-Door Car           17.269323
# 5                  69.0   Personal Auto   Two-Door Car          159.383042
# 6                  67.0  Corporate Auto  Four-Door Car          321.600000
# 8                  71.0  Corporate Auto  Four-Door Car          511.200000
